# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateus-Santana7/Atividade02-Python/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estruturas condicionais
#
#  # IF e ELSE

# %%
idade=int(input("Digite sua idade:"))
if idade >= 18:
    print("Apto para voto")
else :
  print("Não apto para voto")
# Out:
# Digite sua idade:18
# Apto para voto

# %% [markdown]
# # Atividade 1

# %%
senha=input("Digite a senha")
if senha != ("senai2026"):
  print("Acesso Bloqueado")
else:
  print("Acesso Liberado")
# Out:
# Digite a senhasenai2026
# Acesso Liberado

# %%
meta=int(input("Sua Meta"))
if meta >= 8000:
  print("Atingiu a meta")
else:
  print("Não Atingiu a meta")
# Out:
# Sua Meta9500
# Atingiu a meta
